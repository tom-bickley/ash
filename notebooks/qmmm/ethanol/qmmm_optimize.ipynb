# %%
from ash import *
# Out:
# ashpath: /Users/tom/Documents/ucl/projects/ash-fork/ash
# Sys path: ['/Users/tom/Documents/ucl/projects/ash-fork/ash', '/Users/tom/.local/share/uv/python/cpython-3.11.12-macos-aarch64-none/lib/python311.zip', '/Users/tom/.local/share/uv/python/cpython-3.11.12-macos-aarch64-none/lib/python3.11', '/Users/tom/.local/share/uv/python/cpython-3.11.12-macos-aarch64-none/lib/python3.11/lib-dynload', '', '/Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages', '__editable__.ash-0.95.finder.__path_hook__']
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                                            ASH
#                               A MULTISCALE MODELLING PROGRAM
#                                         Version: 0.9dev
#                                Git commit version: Unknown
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# ASH path: /Users/tom/Documents/ucl/projects/ash-fork/ash
# Python version: 3.11.12
# Python interpreter: /Users/tom/Documents/ucl/projects/ash-fork/.venv/bin/python
#
# ASH Settings after reading defaults and ~/ash_user_settings.ini :
# See https://ash.readthedocs.io/en/latest/basics.html#ash-settings on how to change settings.
# 	 debugflag :  False
# 	 load_julia :  False
# 	 julia_library :  pythoncall
# 	 use_ANSI_color :  False
# 	 print_logo :  False
# 	 print_input :  True
# 	 scale :  1.0
# 	 tol :  0.1
# 	 conndepth :  10
# 	 connectivity_code :  julia
# 	 nonbondedMM_code :  julia
# 	 print_exit_footer :  True
# 	 print_full_timings :  True
#
# Note: ASH can use ANSI escape sequences for displaying color. Use e.g. less -R to display
# To turn on/off escape sequences, set: 'use_ANSI_color = False' in
# ~/ash_user_settings.ini

# %%
BASIS = 'sto-3g'
XC = 'b3lyp'
CHARGE = 0
MULT = 1

# %%
#Defining fragment
frag = Fragment(xyzfile="system_aftersolvent.xyz", charge=CHARGE, mult=MULT)
# Out:
# --------------------------------------------------------------------------------
#                                 New ASH fragment
# --------------------------------------------------------------------------------
#
# ASH Fragment creation
# Reading coordinates from XYZ file 'system_aftersolvent.xyz' into fragment.
# Creating/Updating fragment attributes...
# Number of Atoms in fragment: 2637
# Formula: H1758O877C2
# Label: system_aftersolvent
# Charge: 0 Mult: 1
#
# --------------------------------------------------------------------------------

# %%
xyz_list = [i for i in zip(frag.elems, frag.coords)]

lines = [str(len(xyz_list)), '']
for symbol, coords in xyz_list:
    line = f"{symbol} {coords[0]} {coords[1]} {coords[2]}"
    lines.append(line)

xyz_string = "\n".join(lines)

# %%
qm_atoms = list(range(9))

# %%
qm_atoms
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
qm_xyz_list = [
    (frag.elems[i], frag.coords[i])
    for i in qm_atoms
]

lines = [str(len(qm_xyz_list)), '']
for symbol, coords in qm_xyz_list:
    line = f"{symbol} {coords[0]} {coords[1]} {coords[2]}"
    lines.append(line)

qm_xyz_string = "\n".join(lines)
print(qm_xyz_string)
# Out:
# 9
#
# C 0.0 0.0 0.0
# C -1.187 0.984 0.0
# O -2.406 0.224 0.0
# H -3.117 0.913 0.0
# H -1.125 1.631 0.883
# H -1.125 1.631 -0.883
# H 0.939 0.546 0.0
# H -0.036 -0.633 0.881
# H -0.036 -0.633 -0.881

# %%
N_ACT = 2

# %%
nbed_theory = NbedTheory(
    geometry=qm_xyz_string,
    n_active_atoms=N_ACT,
    basis=BASIS,
    xc_functional=XC,
    projector='mu',
    localization='spade',
    # run_ccsd_emb=True
)
# Out:
#                      #####################################
#                      #                                   #
#                      #     NbedTheory initialization     #
#                      #                                   #
#                      #####################################

# %%
# water_xml = "/opt/homebrew/Caskroom/miniconda/base/envs/ash-conda/lib/python3.11/site-packages/openmm/app/data/amber14/tip3p.xml"
water_xml = "amber14/tip3p.xml"

frozen_atoms=listdiff(frag.allatoms,qm_atoms)

openmm_theory = OpenMMTheory(
    xmlfiles=["openff_LIG.xml", water_xml], 
    pdbfile="system_aftersolvent.pdb", 
    # periodic=True, 
    # autoconstraints=None,
    # rigidwater=False,
    # frozen_atoms=qm_atoms,
)
# Out:
#                            #########################
#                            #                       #
#                            #     OpenMM Theory     #
#                            #                       #
#                            #########################
# OpenMM CPU threads set to: 1
# Imported OpenMM library version: 8.3.1
#
# --------------------------------------------------------------------------------
#                              Defining OpenMM object
# --------------------------------------------------------------------------------
#
# Printlevel: 2
# HBonds option: X-H bond lengths will automatically be constrained
# AutoConstraint setting: HBonds
# Rigidwater constraints: True
# Hydrogenmass option: 1.5 Da
# Using platform: CPU
#
# --------------------------------------------------------------------------------
#                             Setting up force fields.
# --------------------------------------------------------------------------------
#
# Note: OpenMM will fail in this step if parameters are missing in topology and
#       parameter files (e.g. nonbonded entries).
#
# Reading OpenMM XML forcefield files and PDB file
# xmlfiles: 'openff_LIG.xml', 'amber14/tip3p.xml'
# pdbfile: system_aftersolvent.pdb
# residueTemplates: {}
# System is non-periodic.
# nonbonded noPBC Method is: NoCutoff
# Nonbonded cutoff : 20 Angstrom
#
# ----------------------
# OpenMM system created.
# ----------------------
# OpenMM Forces defined: [<openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x1647914a0> >, <openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x164791bc0> >, <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x164791710> >, <openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x164791560> >, <openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x164791680> >]
#
# Setting charges
# Number of atoms in OpenMM system: 2637
#
# System constraints defined upon system creation: 2634
# Use printlevel =>3 to see list of all constraints
#
# ----------------------------------------------------------------------------
# Time to calculate step (OpenMM object creation): 0.436 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------

# %%
qmmm_theory = QMMMTheory(
    qm_theory = nbed_theory,
    mm_theory = openmm_theory,
    fragment = frag,
    qm_charge = CHARGE,
    qm_mult = MULT,
    qmatoms = qm_atoms,
    printlevel = 3,
)
# Out:
#                             ########################
#                             #                      #
#                             #     QM/MM Theory     #
#                             #                      #
#                             ########################
# QM-theory: NbedTheory
# MM-theory: OpenMMTheory
# All atoms in fragment: 2637
# QM region (9 atoms): [0, 1, 2, 3, 4, 5, 6, 7, 8]
# MM region (2628 atoms)
# QM/MM object selected to use 1 cores
# Embedding: elstat
# No atomcharges list passed to QMMMTheory object
# Getting system charges from OpenMM object
# QM-region coordinates (before linkatoms):
#    0    C   0.00000000    0.00000000    0.00000000
#    1    C  -1.18700000    0.98400000    0.00000000
#    2    O  -2.40600000    0.22400000    0.00000000
#    3    H  -3.11700000    0.91300000    0.00000000
#    4    H  -1.12500000    1.63100000    0.88300000
#    5    H  -1.12500000    1.63100000   -0.88300000
#    6    H   0.93900000    0.54600000    0.00000000
#    7    H  -0.03600000   -0.63300000    0.88100000
#    8    H  -0.03600000   -0.63300000   -0.88100000
#
# Determining QM-MM/HL-LL boundary
# Parameters determing connectivity:
# Scaling factor: 1.0
# Tolerance: 0.30000000000000004
# QM atoms: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# QM atoms to be excluded from boundary creation (excludeboundaryatomlist):  []
# QM-MM boundary dictionary: {}
#
# ------------------------------------------------------------------------
# Time to calculate step (get_boundary_atoms): 0.001 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
# No covalent QM-MM boundary. Linkatoms and dipole_correction options set to False
# Removing constraints in OpenMM object for atoms: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Removing bonded terms for QM-region in MMtheory
# Modifying bonded forces.
#
#
# Number of bonded terms removed:
# Harmonic Bond terms: 2
# Harmonic Angle terms: 13
# Periodic Torsion terms: 16
# Custom Torsion terms: 0
# CMAP Torsion terms: 0
# CustomBond terms 0
#
#
# --------------------------------------------------------------------------
# Time to calculate step (modify_bonded_forces): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
# Removing nonbonded terms for QM-region in MMtheory (QM-QM interactions)
# atomlist: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Add exceptions/exclusions. Removing i-j interactions for list: 9 atoms
# Case Nonbondedforce. Adding Exception for ij pair.
# Number of exceptions (Nonbondedforce) added: 81
# Number of exclusions (CustomNonbondedforce) added: 0
#
# --------------------------------------------------------------------
# Time to calculate step (add exceptions): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Charges of QM atoms set to 0 (since Electrostatic Embedding):
# Setting QM charges to Zero
#
# -------------------------------------------------------------------
# Time to calculate step (ZeroQMCharges): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
# Updating charges in OpenMM object.
# Updating simulation object for modified Nonbonded force.
#
# --------------------------------------------------------------------
# Time to calculate step (update_charges): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Deleting Coulombexceptions for atomlist: [0, 1, 2, 3, 4, 5, 6, 7, 8]
#
# -----------------------------------------------------------------------
# Time to calculate step (delete_exceptions): 0.003 seconds, 0.0 minutes.
# -----------------------------------------------------------------------
# QM atom 0 (C) charge: 0.0
# QM atom 1 (C) charge: 0.0
# QM atom 2 (O) charge: 0.0
# QM atom 3 (H) charge: 0.0
# QM atom 4 (H) charge: 0.0
# QM atom 5 (H) charge: 0.0
# QM atom 6 (H) charge: 0.0
# QM atom 7 (H) charge: 0.0
# QM atom 8 (H) charge: 0.0
#
#
# ---------------------------------------------------------------------------
# Time to calculate step (QM/MM object creation): 0.007 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------

# %%
qmmm_theory

# %%
MolecularDynamics(
    fragment=frag,
    theory=qmmm_theory,
    timestep=0.001,
    simulation_steps=100,
    traj_frequency=1,
    temperature=300,
    # integrator='LangevinIntegrator',
    coupling_frequency=1,
    charge=CHARGE,
    mult=MULT
)
# Out:
#                      ######################################
#                      #                                    #
#                      #     OpenMM MD wrapper function     #
#                      #                                    #
#                      ######################################
#
#
#               ####################################################
#               #                                                  #
#               #     OpenMM Molecular Dynamics Initialization     #
#               #                                                  #
#               ####################################################
# Analyzing theory input to OpenMM_MDclass
# This is an QMMMTheory object
# Turning on externalforce option.
# Added force
# System is non-periodic. Setting enforcePeriodicBox to False
#
# --------------------
# MD system parameters
# --------------------
# Temperature: 300 K
# OpenMM autoconstraints: HBonds
# OpenMM hydrogenmass: 1.5 Da
# OpenMM rigidwater constraints: True
# User Constraints: []
# User Restraints: []
# Number of atoms: 2637
# Number of frozen atoms: 0
# Frozen atoms []
# Integrator: LangevinMiddleIntegrator
# Timestep: 0.001 ps
# Anderon Thermostat: False
# coupling_frequency: 1 ps^-1 (for Nose-Hoover and Langevin integrators)
# Barostat: None
#
# Will write trajectory in format: DCD
# Trajectory write frequency: 1
# enforcePeriodicBox: False
# special_wrapping: False
# special_wrapping_updatepos: False
# wrapping_atoms: None
#
#
# Defining atom positions from fragment
# enforcePeriodicBox: False
# OpenMM Forces defined: [<openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x1287a8030> >, <openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x1287aadf0> >, <openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x1287aae50> >, <openmm.openmm.CMMotionRemover; proxy of <Swig Object of type 'OpenMM::CMMotionRemover *' at 0x162817510> >, <openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x1628176f0> >, <openmm.openmm.CustomExternalForce; proxy of <Swig Object of type 'OpenMM::CustomExternalForce *' at 0x162817bd0> >]
#
# ---------------------------------------------------------------------
# Time to calculate step (OpenMM_MD setup): 0.005 seconds, 0.0 minutes.
# ---------------------------------------------------------------------
#
#
#                    #########################################
#                    #                                       #
#                    #     OpenMM Molecular Dynamics Run     #
#                    #                                       #
#                    #########################################
# Restart false and no chkfile/statefile set. This is a new simulation
#
# --------------------------------------------------------------------------------
#                    Creating/updating OpenMM simulation object
# --------------------------------------------------------------------------------
#
# Integrator name: LangevinMiddleIntegrator
# Timestep: 0.001
# Temperature: 300
# Coupling frequency: 1
# Properties: {'Threads': '1'}
# Topology: <Topology; 2 chains, 877 residues, 2637 atoms, 1760 bonds>
#
# ----------------------------------------------------------------------------------
# Time to calculate step (creating/updating simulation): 0.005 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# Simulation created.
#
# -----------------
# MD run parameters
# -----------------
# Simulation time: 0.1 ps
# Simulation steps: 100
# Timestep: 0.001 ps
# Set temperature: 300 K
# OpenMM integrator: LangevinMiddleIntegrator
#
# OpenMM System forces present before run: ['HarmonicBondForce', 'PeriodicTorsionForce', 'NonbondedForce', 'CMMotionRemover', 'HarmonicAngleForce', 'CustomExternalForce']
# System is not periodic
# Restart false
# Creating CheckpointReporter that will write a restartable checkpointfile every X steps
# Creating StateDataReporter that will write to stdout
# DCDReporter added
# simulation.reporters: [<openmm.app.checkpointreporter.CheckpointReporter object at 0x163fa5990>, <openmm.app.statedatareporter.StateDataReporter object at 0x162934cd0>, <openmm.app.dcdreporter.DCDReporter object at 0x1644127d0>]
# Setting coordinates of OpenMM object
# Coordinates set
#
# QM/MM MD run beginning
# Step: 0
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.007 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# First QMMMTheory run. Running runprep
# Inside QMMMTheory runprep
#
# -------------------------------------------------------------
# Time to calculate step (runprep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/pyscf/dft/libxc.py:511: UserWarning: Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, corresponding to the original definition by Stephens et al. (issue 1480) and the same as the B3LYP functional in Gaussian. To restore the VWN5 definition, you can put the setting "B3LYP_WITH_VWN5 = True" in pyscf_conf.py
#   warnings.warn('Since PySCF-2.3, B3LYP (and B3P86) are changed to the VWN-RPA variant, '
# converged SCF energy = -153.02650021305  <S^2> = 6.77014e-09  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:126: RuntimeWarning: divide by zero encountered in matmul
#   linalg.fractional_matrix_power(ao_overlap, 0.5) @ occupied_orbitals
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:126: RuntimeWarning: overflow encountered in matmul
#   linalg.fractional_matrix_power(ao_overlap, 0.5) @ occupied_orbitals
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:126: RuntimeWarning: invalid value encountered in matmul
#   linalg.fractional_matrix_power(ao_overlap, 0.5) @ occupied_orbitals
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:154: RuntimeWarning: divide by zero encountered in matmul
#   c_loc_occ = occupied_orbitals @ right_vectors.T
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:154: RuntimeWarning: overflow encountered in matmul
#   c_loc_occ = occupied_orbitals @ right_vectors.T
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/occupied/spade.py:154: RuntimeWarning: invalid value encountered in matmul
#   c_loc_occ = occupied_orbitals @ right_vectors.T
# converged SCF energy = -39.7149622806322  <S^2> = 7.0268984e-08  2S+1 = 1.0000001
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:431: RuntimeWarning: divide by zero encountered in matmul
#   env_projector_alpha = s_mat @ self.localized_system.dm_enviro @ s_mat
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:431: RuntimeWarning: overflow encountered in matmul
#   env_projector_alpha = s_mat @ self.localized_system.dm_enviro @ s_mat
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:431: RuntimeWarning: invalid value encountered in matmul
#   env_projector_alpha = s_mat @ self.localized_system.dm_enviro @ s_mat
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:437: RuntimeWarning: divide by zero encountered in matmul
#   env_projector_beta = s_mat @ self.localized_system.beta_dm_enviro @ s_mat
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:437: RuntimeWarning: overflow encountered in matmul
#   env_projector_beta = s_mat @ self.localized_system.beta_dm_enviro @ s_mat
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/driver.py:437: RuntimeWarning: invalid value encountered in matmul
#   env_projector_beta = s_mat @ self.localized_system.beta_dm_enviro @ s_mat
# Overwritten attributes  get_hcore energy_elec  of <class 'pyscf.scf.uhf.UHF'>
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:140: RuntimeWarning: divide by zero encountered in matmul
#   np.linalg.inv(self.projected_overlap)
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:140: RuntimeWarning: overflow encountered in matmul
#   np.linalg.inv(self.projected_overlap)
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:140: RuntimeWarning: invalid value encountered in matmul
#   np.linalg.inv(self.projected_overlap)
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:145: RuntimeWarning: divide by zero encountered in matmul
#   np.swapaxes(left, -1, -2) @ self.overlap_two_basis @ effective_virt
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:145: RuntimeWarning: overflow encountered in matmul
#   np.swapaxes(left, -1, -2) @ self.overlap_two_basis @ effective_virt
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:145: RuntimeWarning: invalid value encountered in matmul
#   np.swapaxes(left, -1, -2) @ self.overlap_two_basis @ effective_virt
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:168: RuntimeWarning: divide by zero encountered in matmul
#   c_ispan = effective_virt @ v_span
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:168: RuntimeWarning: overflow encountered in matmul
#   c_ispan = effective_virt @ v_span
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/localizers/virtual/concentric.py:168: RuntimeWarning: invalid value encountered in matmul
#   c_ispan = effective_virt @ v_span
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:76: RuntimeWarning: divide by zero encountered in matmul
#   c_matrix_active[0].T @ hcore[0] @ c_matrix_active[0]
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:76: RuntimeWarning: overflow encountered in matmul
#   c_matrix_active[0].T @ hcore[0] @ c_matrix_active[0]
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:76: RuntimeWarning: invalid value encountered in matmul
#   c_matrix_active[0].T @ hcore[0] @ c_matrix_active[0]
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:79: RuntimeWarning: divide by zero encountered in matmul
#   c_matrix_active[1].T @ hcore[1] @ c_matrix_active[1]
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:79: RuntimeWarning: overflow encountered in matmul
#   c_matrix_active[1].T @ hcore[1] @ c_matrix_active[1]
# /Users/tom/Documents/ucl/projects/ash-fork/.venv/lib/python3.11/site-packages/nbed/ham_builder.py:79: RuntimeWarning: invalid value encountered in matmul
#   c_matrix_active[1].T @ hcore[1] @ c_matrix_active[1]
# MM elements: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', ' ...
# E(UCCSD) = -39.86118487227498  E_corr = -0.146222591642772
# UCCSD(T) correction = -0.000531994187038926
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C     0.0018568683    -0.0015798040    -0.0000000000
# 1 C    -0.0035632880    -0.0041267274    -0.0000000000
# 2 O    -0.0052895630     0.0474029013    -0.0000000000
# 3 H     0.0236422321    -0.0290094549    -0.0000000000
# 4 H    -0.0037401408    -0.0104473539    -0.0119332633
# 5 H    -0.0037401408    -0.0104473539     0.0119332633
# 6 H    -0.0098717290    -0.0057835060     0.0000000000
# 7 H     0.0003301200     0.0070048710    -0.0096570351
# 8 H     0.0003301200     0.0070048710     0.0096570351
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 5.3882598876953125e-05
# Time for setup 2: 0.001425027847290039
# Time for setup 4: 0.2574167251586914
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.953 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: -0.3103096459480489
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.954 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Step 0. Saving a statefile and checkpointfile : OpenMM_MD_state.xml and OpenMM_MD_checkpoint.chk
# Can be used to restart a simulation (statefile and chkfile keywords) using the same coordinates and velocities.
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# #"Step","Time (ps)","Potential Energy (kJ/mole)","Kinetic Energy (kJ/mole)","Temperature (K)"
# 1,0.001,-29610.299311035847,59.46361503936902,2.709026143992036
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.016 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.984 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Step: 1
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.004 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# converged SCF energy = -153.027847667412  <S^2> = 7.7439779e-09  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
#
# converged SCF energy = -39.8053166234955  <S^2> = 7.8570697e-08  2S+1 = 1.0000002
# MM elements: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', ' ...
# E(UCCSD) = -39.95243565099873  E_corr = -0.1471190275032618
# UCCSD(T) correction = -0.000539966882732204
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C    -0.0005725232     0.0006824017     0.0002003805
# 1 C    -0.0040183808    -0.0086347026     0.0001646426
# 2 O     0.0047044879     0.0366095848    -0.0000072858
# 3 H     0.0133632585    -0.0187517908     0.0000017948
# 4 H    -0.0033066722    -0.0080452319    -0.0087194201
# 5 H    -0.0033186989    -0.0078978630     0.0085363366
# 6 H    -0.0071389340    -0.0040696540    -0.0000115915
# 7 H     0.0001256275     0.0051113434    -0.0070142000
# 8 H     0.0001149666     0.0050143697     0.0068493370
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 3.5762786865234375e-05
# Time for setup 2: 0.0015108585357666016
# Time for setup 4: 0.25583791732788086
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.730 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: -0.24563259402122387
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.731 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# 2,0.002,-29598.680682897026,194.20387308279393,8.847483778062992
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.009 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.747 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Step: 2
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.004 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# converged SCF energy = -153.029021687653  <S^2> = 9.8775796e-09  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
#
# converged SCF energy = -39.9552830184892  <S^2> = 9.6105738e-08  2S+1 = 1.0000002
# MM elements: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', ' ...
# E(UCCSD) = -40.10402629018235  E_corr = -0.1487432716931837
# UCCSD(T) correction = -0.000554619671558486
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C    -0.0043262389     0.0043199754     0.0006265006
# 1 C    -0.0048944129    -0.0158208666     0.0005654670
# 2 O     0.0186736179     0.0202513781     0.0000106537
# 3 H    -0.0013888801    -0.0036506834    -0.0000035052
# 4 H    -0.0025315389    -0.0039553885    -0.0031323576
# 5 H    -0.0024877866    -0.0035335051     0.0025797286
# 6 H    -0.0025721815    -0.0012107716    -0.0000597959
# 7 H    -0.0002924632     0.0020107236    -0.0026557971
# 8 H    -0.0002292380     0.0016070702     0.0020690539
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 0.000270843505859375
# Time for setup 2: 0.0010378360748291016
# Time for setup 4: 0.2563767433166504
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.766 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: -0.13813059864928098
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.767 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# 3,0.003,-29539.444428253435,399.59697703699663,18.20472329401277
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.009 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.783 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Step: 3
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.004 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# converged SCF energy = -153.028956372079  <S^2> = 1.3051531e-08  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
#
# converged SCF energy = -40.1178336498277  <S^2> = 1.2157874e-07  2S+1 = 1.0000002
# MM elements: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', ' ...
# E(UCCSD) = -40.26855531068136  E_corr = -0.1507216608536208
# UCCSD(T) correction = -0.000572783950936429
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C    -0.0076904481     0.0079524472     0.0008701644
# 1 C    -0.0060576360    -0.0227813232     0.0009399726
# 2 O     0.0299037988     0.0044217271     0.0000533652
# 3 H    -0.0140322121     0.0100073735    -0.0000143642
# 4 H    -0.0015293174     0.0007587545     0.0034367074
# 5 H    -0.0013604407     0.0013556953    -0.0042541462
# 6 H     0.0020499828     0.0017556984    -0.0000844116
# 7 H    -0.0007773083    -0.0013455583     0.0021135568
# 8 H    -0.0005580397    -0.0021084889    -0.0030608815
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 0.0002899169921875
# Time for setup 2: 0.0011119842529296875
# Time for setup 4: 0.2737131118774414
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.794 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.000 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: -0.021551424931255884
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.795 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# 4,0.004,-29514.12141038809,666.3407206115518,30.356957473037305
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.009 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.812 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Step: 4
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.004 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.000 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# converged SCF energy = -153.028150036329  <S^2> = 1.6197705e-08  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
#
# converged SCF energy = -40.2563370403434  <S^2> = 1.4733886e-07  2S+1 = 1.0000003
# ...
# E(UCCSD) = -40.69159575018639  E_corr = -0.1528718921953517
# UCCSD(T) correction = -0.000584652581876659
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C     0.0239203710    -0.0095612193     0.0037344758
# 1 C    -0.0048798999     0.0207083771     0.0058364961
# 2 O    -0.0177795348     0.0093278401     0.0010447463
# 3 H     0.0138531565    -0.0096725973     0.0013044504
# 4 H    -0.0057904893    -0.0106242169    -0.0126316527
# 5 H    -0.0000285684    -0.0029453465     0.0060284134
# 6 H    -0.0006093962     0.0020277032    -0.0021347959
# 7 H    -0.0049458216     0.0002485381    -0.0054418344
# 8 H    -0.0037236227     0.0004989964     0.0023006857
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 0.0005786418914794922
# Time for setup 2: 0.0020339488983154297
# Time for setup 4: 0.2837178707122803
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.897 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.001 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.002 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: -0.030403344778625323
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.906 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# 99,0.09900000000000007,-33347.40976933729,5098.157441665673,232.26037950292795
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.010 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.928 seconds, 0.0 minutes.
# --------------------------------------------------------------------
# Step: 99
#
# ----------------------------------------------------------------------
# Time to calculate step (get OpenMM state): 0.004 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Time to calculate step (get current_coords): 0.000 seconds, 0.0 minutes.
# ------------------------------------------------------------------------
#   ------------RUNNING QM/MM MODULE-------------
# QM Module: NbedTheory
# MM Module: OpenMMTheory
# Charge provided from QMMMTheory object:  0
# Mult provided from QMMMTheory object:  1
# QM-region Charge: 0 Mult: 1
# Embedding: Electrostatic
# Number of pointcharges (to QM program): 2628
# Number of charge coordinates: 2628
# Running QM/MM object with 1 cores available
#
# -------------------------------------------------------------------
# Time to calculate step (before-QMstep): 0.001 seconds, 0.0 minutes.
# -------------------------------------------------------------------
#   ------------RUNNING Nbed INTERFACE-------------
# Job label: None
# converged SCF energy = -153.028663403007  <S^2> = 1.4209784e-08  2S+1 = 1
#
# WARN: Incompatible dm dimension. Treat dm as RHF density matrix.
#
# converged SCF energy = -40.6238977979465  <S^2> = 9.4373744e-08  2S+1 = 1.0000002
# MM elements: ['O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', 'H', 'O', 'H', ' ...
# E(UCCSD) = -40.77791862555883  E_corr = -0.1540208276122952
# UCCSD(T) correction = -0.00059584260130638
# --------------- UKS gradients ---------------
#          x                y                z
# 0 C     0.0175073821    -0.0040317145     0.0091405656
# 1 C    -0.0076408712     0.0125797812     0.0065639034
# 2 O    -0.0015285812    -0.0024141057     0.0029033625
# 3 H    -0.0013410817     0.0032018855    -0.0011740059
# 4 H    -0.0042664013    -0.0073648364    -0.0076268945
# 5 H     0.0007106209    -0.0010250925     0.0005006464
# 6 H     0.0056772826     0.0057884982    -0.0024714533
# 7 H    -0.0045125790    -0.0014336422    -0.0035669678
# 8 H    -0.0045876685    -0.0052920722    -0.0042266701
# ----------------------------------------------
# Einsumfunc from: numpy
# Time for setup 1: 0.0005559921264648438
# Time for setup 2: 0.0024199485778808594
# Time for setup 4: 0.28488707542419434
#
# -------------------------------------------------------------
# Time to calculate step (QM step): 1.884 seconds, 0.0 minutes.
# -------------------------------------------------------------
#
# ----------------------------------------------------------------------
# Time to calculate step (QMpcgrad prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
#
# --------------------------------------------------------------------------
# Time to calculate step (linkatomgrad prepare): 0.001 seconds, 0.0 minutes.
# --------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------
# Time to calculate step (QM/MM gradient prepare): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------
# Using OpenMM theory as part of QM/MM.
# Using MM on full system. Charges for QM region [0, 1, 2, 3, 4, 5, 6, 7, 8] have been set to zero
# OpenMM externalforce is True
# Extforce energy: 0.061963537282360495
#
# ----------------------------------------------------------------------
# Time to calculate step (extforce prepare): 0.000 seconds, 0.0 minutes.
# ----------------------------------------------------------------------
# OpenMM custom external force updated. Exit requested
#
# ---------------------------------------------------------------
# Time to calculate step (QM/MM run): 1.893 seconds, 0.0 minutes.
# ---------------------------------------------------------------
# Writing wrapped coords to trajfile: OpenMMMD_traj_wrapped.xyz (for debugging)
# Updating custom external force
#
# ----------------------------------------------------------------------------------
# Time to calculate step (update custom external force): 0.001 seconds, 0.0 minutes.
# ----------------------------------------------------------------------------------
# 100,0.10000000000000007,-33124.59375217304,5129.424477318228,233.68483405335888
#
# ---------------------------------------------------------------------------
# Time to calculate step (openmmobject sim step): 0.010 seconds, 0.0 minutes.
# ---------------------------------------------------------------------------
#
# --------------------------------------------------------------------
# Time to calculate step (Total sim step): 1.915 seconds, 0.0 minutes.
# --------------------------------------------------------------------
#
# ------------------------------
# OpenMM MD simulation finished!
# ------------------------------
#
# ---------------------------------------------------------------------
# Time to calculate step (OpenMM_MD run): 187.603 seconds, 3.1 minutes.
# ---------------------------------------------------------------------
# Finalizing simulation data
# Writing final frame to disk as PDB-file: trajectory_lastframe.pdb
# Trajectory : trajectory.DCD
# Saving a statefile and checkpointfile of the final frame of the simulation: OpenMM_MD_final_state.xml and OpenMM_MD_final_checkpoint.chk
# These file can be used to restart a simulation (statefile and chkfile keywords) using the same coordinates and velocities.
# Updating coordinates in ASH fragment.

# %%
# Optimizer(
#     fragment=frag, 
#     theory=qmmm_theory, 
#     ActiveRegion=True, 
#     actatoms=qm_atoms
# )
